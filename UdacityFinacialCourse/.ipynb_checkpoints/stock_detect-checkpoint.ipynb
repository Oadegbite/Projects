# %%
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv("GOOG.csv", index_col="Date", parse_dates=True,)

# %%
df[["Adj Close"]].plot()

# %%
df[["Volume"]]
# Out:
#               Volume
# Date
# 2004-08-19  44994500
# 2004-08-20  23005800
# 2004-08-23  18393200
# 2004-08-24  15361800
# 2004-08-25   9257400
# 2004-08-26   7148200
# 2004-08-27   6258300
# 2004-08-30   5235700
# 2004-08-31   4954800
# 2004-09-01   9206800
# 2004-09-02  15232100
# 2004-09-03   5191000
# 2004-09-07   5891300
# 2004-09-08   5023000
# 2004-09-09   4092100
# 2004-09-10   8764200
# 2004-09-13   7902900
# 2004-09-14  10910200
# 2004-09-15  10793500
# 2004-09-16   9335800
# 2004-09-17   9543500
# 2004-09-20  10708500
# 2004-09-21   7282900
# 2004-09-22   7638000
# 2004-09-23   8599600
# 2004-09-24   9191900
# 2004-09-27   7119100
# 2004-09-28  17056100
# 2004-09-29  30745600
# 2004-09-30  13861300
# ...              ...
# 2018-07-23   2619200
# 2018-07-24   3318200
# 2018-07-25   2127800
# 2018-07-26   2405600
# 2018-07-27   2130600
# 2018-07-30   1849900
# 2018-07-31   1644700
# 2018-08-01   1567200
# 2018-08-02   1531300
# 2018-08-03   1089600
# 2018-08-06   1081700
# 2018-08-07   1494000
# 2018-08-08   1370300
# 2018-08-09    841800
# 2018-08-10   1108700
# 2018-08-13    958100
# 2018-08-14   1348100
# 2018-08-15   1828800
# 2018-08-16   1343200
# 2018-08-17   1389600
# 2018-08-20    870800
# 2018-08-21   1205600
# 2018-08-22    887400
# 2018-08-23    992600
# 2018-08-24    946600
# 2018-08-27   1156300
# 2018-08-28   1304000
# 2018-08-29   1298900
# 2018-08-30   1331400
# 2018-08-31   1812800
#
# [3535 rows x 1 columns]

# %%
df2 = df[["Adj Close"]]

# %%
df2.plot()

# %%
def dfPlot(dataFrame,title="Stock prices"):
    ax = dataFrame.plot(title=title,fontsize=10)
    ax.set_xlabel("Date")
    ax.set_ylabel("Price")

# %%
#dfPlot(df2.rolling(window=20).mean())

# %%
start_date = '2017-01-01'
end_date = '2017-12-31'
dates = pd.date_range(start_date,end_date)

# %%
dfRollingMean = df2.rolling(window=20).mean()

# %%
dfRollingMean['2011-10-10':]
# Out:
#               Adj Close
# Date
# 2011-10-10   261.827811
# 2011-10-11   262.167104
# 2011-10-12   262.575199
# 2011-10-13   262.983295
# 2011-10-14   264.101026
# 2011-10-17   264.988754
# 2011-10-18   266.078664
# 2011-10-19   267.109460
# 2011-10-20   268.674531
# 2011-10-21   270.288534
# 2011-10-24   271.891358
# 2011-10-25   272.979778
# 2011-10-26   274.407244
# 2011-10-27   276.174996
# 2011-10-28   278.288748
# 2011-10-31   280.701059
# 2011-11-01   282.607411
# 2011-11-02   284.597467
# 2011-11-03   286.653843
# 2011-11-04   288.666254
# 2011-11-07   290.433759
# 2011-11-08   292.151585
# 2011-11-09   293.454363
# 2011-11-10   294.350783
# 2011-11-11   294.764839
# 2011-11-14   295.524648
# 2011-11-15   296.171690
# 2011-11-16   296.935970
# 2011-11-17   297.363191
# 2011-11-18   297.472232
# ...                 ...
# 2018-07-23  1153.045502
# 2018-07-24  1159.208997
# 2018-07-25  1166.470996
dfSTD = df2.rolling(window=20).std()

# %%
dfSTD
# Out:
#             Adj Close
# Date
# 2004-08-19        NaN
# 2004-08-20        NaN
# 2004-08-23        NaN
# 2004-08-24        NaN
# 2004-08-25        NaN
# 2004-08-26        NaN
# 2004-08-27        NaN
# 2004-08-30        NaN
# 2004-08-31        NaN
# 2004-09-01        NaN
# 2004-09-02        NaN
# 2004-09-03        NaN
# 2004-09-07        NaN
# 2004-09-08        NaN
# 2004-09-09        NaN
# 2004-09-10        NaN
# 2004-09-13        NaN
# 2004-09-14        NaN
# 2004-09-15        NaN
# 2004-09-16   2.104306
# 2004-09-17   2.419974
# 2004-09-20   2.826013
# 2004-09-21   3.075604
# 2004-09-22   3.305216
# 2004-09-23   3.598076
# 2004-09-24   3.808896
# 2004-09-27   3.921906
# 2004-09-28   4.244665
# 2004-09-29   4.666014
# 2004-09-30   4.809459
# ...               ...
# 2018-07-23  35.148809
# 2018-07-24  40.358831
# 2018-07-25  45.393608
# 2018-07-26  48.270394
# 2018-07-27  48.075477
# 2018-07-30  46.238801
# 2018-07-31  44.574208
# 2018-08-01  39.892683
# 2018-08-02  36.555402
# 2018-08-03  33.845447
# 2018-08-06  31.794787
# 2018-08-07  29.656776
# 2018-08-08  26.879183
# 2018-08-09  26.404070
# 2018-08-10  25.453288
# 2018-08-13  23.714454
# 2018-08-14  23.009665
# 2018-08-15  21.966625
# 2018-08-16  20.341461
# 2018-08-17  18.691275
# 2018-08-20  18.531539
# 2018-08-21  19.251660
# 2018-08-22  18.030583
# 2018-08-23  15.672196
# 2018-08-24  15.263110
# 2018-08-27  15.848390
# 2018-08-28  15.865000
# 2018-08-29  16.783916
# 2018-08-30  17.052408
# 2018-08-31  17.141062
#
# [3535 rows x 1 columns]

# %%
upperBand, lowerBand = get_bollinger_bands(dfRollingMean, dfSTD)

# %%
upperBand
# Out:
# Date
# 2004-08-19            NaN
# 2004-08-20            NaN
# 2004-08-23            NaN
# 2004-08-24            NaN
# 2004-08-25            NaN
# 2004-08-26            NaN
# 2004-08-27            NaN
# 2004-08-30            NaN
# 2004-08-31            NaN
# 2004-09-01            NaN
# 2004-09-02            NaN
# 2004-09-03            NaN
# 2004-09-07            NaN
# 2004-09-08            NaN
# 2004-09-09            NaN
# 2004-09-10            NaN
# 2004-09-13            NaN
# 2004-09-14            NaN
# 2004-09-15            NaN
# 2004-09-16      56.508700
# 2004-09-17      57.566015
# 2004-09-20      58.652558
# 2004-09-21      59.361377
# 2004-09-22      60.156168
# 2004-09-23      61.109995
# 2004-09-24      61.827707
# 2004-09-27      62.354523
# 2004-09-28      63.617276
# 2004-09-29      65.173086
# 2004-09-30      66.188983
#                  ...
# 2018-07-23    1223.343119
# 2018-07-24    1239.926659
# 2018-07-25    1257.258212
# 2018-07-26    1271.229283
# 2018-07-27    1277.053449
# 2018-07-30    1278.584596
# 2018-07-31    1279.745413
# 2018-08-01    1276.238362
# 2018-08-02    1274.657801
# 2018-08-03    1273.414888
# 2018-08-06    1272.849565
# 2018-08-07    1273.042543
# 2018-08-08    1272.072856
# 2018-08-09    1274.403629
# 2018-08-10    1274.941567
# 2018-08-13    1274.021400
# 2018-08-14    1274.776819
# 2018-08-15    1273.615739
# 2018-08-16    1271.341913
# 2018-08-17    1268.844037
# 2018-08-20    1268.638065
# 2018-08-21    1267.755310
# 2018-08-22    1262.494656
# 2018-08-23    1254.630385
# 2018-08-24    1252.919715
# 2018-08-27    1255.194272
# 2018-08-28    1255.921993
# 2018-08-29    1259.224325
# 2018-08-30    1260.409809
# 2018-08-31    1260.311116
# Length: 3535, dtype: float64

# %%
upperBand.columns = ["Upper Band"]

# %%
lowerBand.columns = ["Lower Band"]

# %%
ax = df2.plot(title="Bollinger Bands")
dfRollingMean.plot(label='Rolling mean', ax=ax) #how to fix labels?
upperBand.plot(label='upper band', ax=ax)
lowerBand.plot(label='lower band', ax=ax)
anomDF.plot(style="*", x="Date" ,y="Price",  ax=ax)
anomDFhi.plot(style="*", x="Date" ,y="High Price",  ax=ax,color="r")
anomDFlo.plot(style="*", x="Date" ,y="Low Price",  ax=ax,color="b", figsize=(15,8))


ax.set_xlabel("Date")
ax.set_ylabel("Price")
ax.legend(loc='upper left')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-f90955ddd4ef> in <module>
#       3 upperBand.plot(label='upper band', ax=ax)
#       4 lowerBand.plot(label='lower band', ax=ax)
# ----> 5 anomDF.plot(style="*", x="Date" ,y="Price",  ax=ax)
#       6 anomDFhi.plot(style="*", x="Date" ,y="High Price",  ax=ax,color="r")
#       7 anomDFlo.plot(style="*", x="Date" ,y="Low Price",  ax=ax,color="b", figsize=(15,8))
#
# NameError: name 'anomDF' is not defined

# %%
anL,anHL,anLL = markAnom(df2,upperBand,lowerBand)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-72-e526bf978f9f> in <module>
# ----> 1 anL,anHL,anLL = markAnom(df2,upperBand,lowerBand)
#
# <ipython-input-69-e6ab8e03f285> in markAnom(df, upper_band, lower_band)
#       5     for index, row in df.iterrows():
#       6         #print(df.loc[index]["Adj Close"])
# ----> 7         if df.loc[index]["Adj Close"] > upper_band.loc[index]["Upper Band"]:
#       8             anomList.append({"Date" : index, "Price" : df.loc[index]["Adj Close"]})
#       9             hi_list.append({"Date" : index, "High Price" : df.loc[index]["Adj Close"]})
#
# IndexError: invalid index to scalar variable.

# %%
anomDF = pd.DataFrame(anL)
anomDFhi = pd.DataFrame(anHL)
anomDFlo = pd.DataFrame(anLL)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-a187b9caf520> in <module>
# ----> 1 anomDF = pd.DataFrame(anL)
#       2 anomDFhi = pd.DataFrame(anHL)
#       3 anomDFlo = pd.DataFrame(anLL)
#
# NameError: name 'anL' is not defined

# %%
anomDF.mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-aeaeee379136> in <module>
# ----> 1 anomDF.mean()
#
# NameError: name 'anomDF' is not defined

# %%
anomDFlo
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-2a32d80508e5> in <module>
# ----> 1 anomDFlo
#
# NameError: name 'anomDFlo' is not defined

# %%
anomDF["Date"] = pd.to_datetime(anomDF["Date"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-8d3fa74ddd98> in <module>
# ----> 1 anomDF["Date"] = pd.to_datetime(anomDF["Date"])
#
# NameError: name 'anomDF' is not defined

# %%
anomDFhi["Date"] = pd.to_datetime(anomDFhi["Date"])

# %%
anomDFlo["Date"] = pd.to_datetime(anomDFlo["Date"])

# %%
result = (1234*115603)+1234

# %%
result % 13
# Out:
# 5

# %%
pyStr = "Hello World"

# %%
pyStr[0:2]
# Out:
# 'He'

# %%
pyStr[2:]
# Out:
# 'llo World'

# %%
def CreateBuillingerBands(df):
    
    dfRollingMean = df.rolling(window=20).mean()
    dfSTD = df.rolling(window=20).std()
    
    dfRollingMean.columns = ["Rolling Mean"]
    
    upperBand, lowerBand = get_bollinger_bands(dfRollingMean, dfSTD)
    
    
    
    upperBand.columns = ["Upper Band"]
    lowerBand.columns = ["Lower Band"]
    print("Upper: {},Lower: {}".format(type(upperBand),type(lowerBand)))
    return
    anL,anHL,anLL = markAnom(df,upperBand,lowerBand)
    
    anomDF = pd.DataFrame(anL)
    anomDFhi = pd.DataFrame(anHL)
    anomDFlo = pd.DataFrame(anLL)
    print(anomDFlo)
    
    anomDF["Date"] = pd.to_datetime(anomDF["Date"])
    anomDFhi["Date"] = pd.to_datetime(anomDFhi["Date"])
    anomDFlo["Date"] = pd.to_datetime(anomDFlo["Date"])
    
    ax = df.plot(title="Bollinger Bands")
    dfRollingMean.plot(label='Rolling mean', ax=ax) #how to fix labels?
    upperBand.plot(label='upper band', ax=ax)
    lowerBand.plot(label='lower band', ax=ax)
    anomDF.plot(style="*", x="Date" ,y="Price",  ax=ax)
    anomDFhi.plot(style="*", x="Date" ,y="High Price",  ax=ax,color="r")
    anomDFlo.plot(style="*", x="Date" ,y="Low Price",  ax=ax,color="b", figsize=(15,10))


    ax.set_xlabel("Date")
    ax.set_ylabel("Price")
    ax.legend(loc='upper left')

# %%
def markAnom(df, upper_band, lower_band):
    anomList = list()
    hi_list = list()
    lo_list = list()
    for index, row in df.iterrows():
        print("{}, {}".format(df.loc[index]["Adj Close"],upper_band.loc[index]["Upper Band"]))
        if df.loc[index]["Adj Close"] > upper_band.loc[index]["Upper Band"]:
            anomList.append({"Date" : index, "Price" : df.loc[index]["Adj Close"]})
            hi_list.append({"Date" : index, "High Price" : df.loc[index]["Adj Close"]})
        if df.loc[index]["Adj Close"] < lower_band.loc[index]["Lower Band"]:
            anomList.append({"Date" : index, "Price" : df.loc[index]["Adj Close"]})
            lo_list.append({"Date" : index, "Low Price" : df.loc[index]["Adj Close"]})
    return anomList, hi_list, lo_list

# %%
def get_bollinger_bands(rm, rstd):
    """Return upper and lower Bollinger Bands."""
    # TODO: Compute upper_band and lower_band
    upper_band = rm['Rolling Mean'] + 2*(rstd['Adj Close'])
    lower_band = rm['Rolling Mean'] - 2*(rstd['Adj Close'])
    return upper_band, lower_band

# %%
dfFB = pd.read_csv("FB.csv", index_col="Date", parse_dates=True,)

# %%
CreateBuillingerBands(dfFB[["Adj Close"]])
# Out:
# Upper: Date
# 2012-05-18           NaN
# 2012-05-21           NaN
# 2012-05-22           NaN
# 2012-05-23           NaN
# 2012-05-24           NaN
# 2012-05-25           NaN
# 2012-05-29           NaN
# 2012-05-30           NaN
# 2012-05-31           NaN
# 2012-06-01           NaN
# 2012-06-04           NaN
# 2012-06-05           NaN
# 2012-06-06           NaN
# 2012-06-07           NaN
# 2012-06-08           NaN
# 2012-06-11           NaN
# 2012-06-12           NaN
# 2012-06-13           NaN
# 2012-06-14           NaN
# 2012-06-15     35.682916
# 2012-06-18     33.898611
# 2012-06-19     33.411733
# 2012-06-20     33.507637
# 2012-06-21     33.477627
# 2012-06-22     33.482428
# 2012-06-25     33.510995
# 2012-06-26     34.084859
# 2012-06-27     34.446414
# 2012-06-28     34.611378
# 2012-06-29     34.761409
#                  ...
# 2018-07-23    214.584222
# 2018-07-24    216.239362
# 2018-07-25    218.390875
# 2018-07-26    222.009377
# 2018-07-27    224.796118
# 2018-07-30    227.517641
# 2018-07-31    229.247995
# 2018-08-01    230.729728
# 2018-08-02    231.211711
# 2018-08-03    231.016508
# 2018-08-06    230.177744
# 2018-08-07    229.377105
# 2018-08-08    228.554853
# 2018-08-09    227.110723
# 2018-08-10    225.459032
# 2018-08-13    223.592826
# 2018-08-14    220.987196
# 2018-08-15    218.177492
# 2018-08-16    215.309763
# 2018-08-17    211.554463
# 2018-08-20    206.863878
# 2018-08-21    199.661109
# 2018-08-22    186.761464
# 2018-08-23    186.791200
# 2018-08-24    186.791702
# 2018-08-27    186.675913
# 2018-08-28    186.591758
# 2018-08-29    186.396208
# 2018-08-30    186.431715
# 2018-08-31    186.385985
# Length: 1583, dtype: float64,Lower: Date
# 2012-05-18           NaN
# 2012-05-21           NaN
# 2012-05-22           NaN
# 2012-05-23           NaN
# 2012-05-24           NaN
# 2012-05-25           NaN
# 2012-05-29           NaN
# 2012-05-30           NaN
# 2012-05-31           NaN
# 2012-06-01           NaN
# 2012-06-04           NaN
# 2012-06-05           NaN
# 2012-06-06           NaN
# 2012-06-07           NaN
# 2012-06-08           NaN
# 2012-06-11           NaN
# 2012-06-12           NaN
# 2012-06-13           NaN
# 2012-06-14           NaN
# 2012-06-15     23.069084
# 2012-06-18     24.171389
# 2012-06-19     24.446266
# 2012-06-20     24.410363
# 2012-06-21     24.424373
# 2012-06-22     24.421571
# 2012-06-25     24.408005
# 2012-06-26     24.260140
# 2012-06-27     24.302586
# 2012-06-28     24.313622
# 2012-06-29     24.501591
#                  ...
# 2018-07-23    190.824777
# 2018-07-24    191.001637
# 2018-07-25    190.700124
# 2018-07-26    185.123622
# 2018-07-27    180.202880
# 2018-07-30    175.155357
# 2018-07-31    170.947003
# 2018-08-01    167.357270
# 2018-08-02    164.667286
# 2018-08-03    162.317490
# 2018-08-06    161.251254
# 2018-08-07    160.078893
# 2018-08-08    159.165145
# 2018-08-09    158.226275
# 2018-08-10    157.171965
# 2018-08-13    156.320172
# 2018-08-14    156.037802
# 2018-08-15    155.864505
# 2018-08-16    155.393234
# 2018-08-17    155.534534
# 2018-08-20    156.384119
# 2018-08-21    159.381888
# 2018-08-22    167.895532
# 2018-08-23    167.529796
# 2018-08-24    167.505294
# 2018-08-27    168.261084
# 2018-08-28    168.713238
# 2018-08-29    169.333788
# 2018-08-30    169.425281
# 2018-08-31    169.266011
# Length: 1583, dtype: float64

# %%
# !ls
# Out:
# CAT_All_Events_Json_specV2_15K.txt
# CATtrail.txt
# FB.csv
# GOOS.TO.csv
# PS_20174392719_1491204439457_log.csv
# Untitled.ipynb
# Untitled1.ipynb
# Untitled2.ipynb
# catTrailTransform.ipynb
# predicting-fraud-in-financial-payment-services.ipynb
# statsCanZipTest.ipynb
# stock_detect.ipynb
# sunspots.txt
# wget-log
