# %%
from urllib.request import urlopen
import pandas as pd
from bs4 import BeautifulSoup

# %%
myList = pd.read_csv("quotes.csv")
Following = myList['Symbol']

# %%
url = "https://finance.yahoo.com/quote/{}/history?p={}".format{symbol} # for future pulling from yahoo?
# Out:
#   File "<ipython-input-12-101b8674de41>", line 1
#     url = "https://finance.yahoo.com/quote/{}/history?p={}".format{symbol} # for future pulling from yahoo?
#                                                                   ^
# SyntaxError: invalid syntax

# %%
url = "https://finance.yahoo.com/quote/{0}/history?p={0}"

# %%
print(url.format("AAPL"))
# Out:
# https://finance.yahoo.com/quote/AAPL/history?p=AAPL

# %%
opened = urlopen(url.format("AAPL"))

# %%
soup = BeautifulSoup(urlopen(url.format("AAPL")),'html.parser')

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html class="NoJs featurephone" id="atomic" lang="en-US">\n <head prefix="og: http://ogp.me/ns#">\n  <script>\n   window.performance && window.performance.mark && window.performance.mark(\'PageStart\');\n  </script>\n  <meta charset="utf-8"/>\n  <title>\n   AAPL Historical Prices | Apple Inc. Stock - Yahoo Finance\n  </title>\n  <meta content="AAPL, Apple Inc., AAPL historical prices, Apple Inc. historical prices, historical prices, stocks, quotes, finance" name="keywords"/>\n  <meta content="on" http-equiv="x-dns-prefetch-control"/>\n  <meta content="on" property="twitter:dnt"/>\n  <meta content="90376669494" property="fb:app_id"/>\n  <meta content="#400090" name="theme-color"/>\n  <meta content="width=device-width, initial-scale=1" name="viewport"/>\n  <meta content="Discover historical prices for AAPL stock on Yahoo Finance. View daily, weekly or monthly format back to when Apple Inc. stock was issued." lang="en-US" name="description"/>\n  <link href="//l.yimg.co
# ...

# %%
link = soup.find('a',attrs={'class':'Fl(end) Mt(3px) Cur(p)'}).getText()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-777dea1b9718> in <module>()
# ----> 1 link = soup.find('a',attrs={'class':'Fl(end) Mt(3px) Cur(p)'}).getText()
#
# AttributeError: 'NoneType' object has no attribute 'getText'

# %%
link
