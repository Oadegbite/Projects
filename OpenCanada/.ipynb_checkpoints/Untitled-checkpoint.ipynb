# %%
"""
 Simple example of a Python script used to query an API.
 
 @note:    This is a simple example without any error handling.
 @license: http://data.gc.ca/eng/open-government-licence-canada
"""
import json
import requests
 
url      = 'https://open.canada.ca/data/en/api/3/action/package_search?q='
search   = "spending"
options  = { "Accept":"application/json", "Accept-Language":"en" }
response = requests.get(url+search, headers=options)
jdata    = response.json()

# %%
print(jdata["result"]["count"])
# Out:
# {'count': 435, 'sort': 'score desc, metadata_modified desc', 'search_facets': {}, 'facets': {}, 'results': [{'notes_translated': {'fr': 'Ce tableau présente les dépenses prévues par programme selon les plans ministériels. Il relie chaque programme à son secteur des dépenses et d’activités du gouvernement du Canada correspondant.\r\n\r\n\r\nRemarque :\r\nPour la plupart des organisations, les données sur les dépenses prévues proviennent des plans ministériels de 2017-2018. Pour tracer un portrait plus complet des dépenses globales prévues du gouvernement, ce tableau renferme aussi des données sur les dépenses prévues de 2017-2018 des organisations qui ne sont pas tenues d’établir un plan ministériel, notamment :\r\n* les sociétés d’État;\r\n* les entités parlementaires;\r\n* la Commission mixte internationale (section canadienne)\r\n* le Bureau du Secrétariat du gouverneur général \r\n* le Centre de la sécurité des télécommunications et\r\n* le Centre de la sécurité des télécommunications\r\n\r\n\r\nPour ces organisations, ce tableau reproduit les données sur les dépenses prévues figurant au budget principal des dépenses de 2017-2018. Les renseignements sur les dépenses prévues de la Société canadienne d’hypothèques et de logement, reproduits ici, ont été directement transmis au Secrétariat par l’organisation aux fins de publication dans l’InfoBase du SCT.', 'en': 'This table presents planned spending by Program based on Departmental Plans. This table also aligns planned spending with the Whole-of-Government framework by linking each Program spending line with its corresponding Government of Canada Spending and Activity Areas.\r\n\r\n\r\nIn order to provide a more complete picture of the government’s overall planned spending, this table also contains planned spending information for organizations that are not required to provide a Departmental Plan, notably: Crown corporations; Parliamentary entities; the International Joint Commission (Canadian Section); the Office of the Governor General’s Secretary; the Canadian Security Intelligence Service; and the Communication Security Establishment.\r\n\r\n\r\nFor these organizations, this table reproduces the planned spending information found in the Main Estimates. Planned spending information shown for the Canada Mortgage and Housing Corporation is provided directly by the organization to TBS for the purposes of the TBS InfoBase and is reproduced here.'}, 'imso_approval': 'true', 'maintainer': None, 'creator': '', 'association_type': [], 'org_section': {'fr': '', 'en': ''}, 'jurisdiction': 'federal', 'private': False, 'maintainer_email': 'open-ouvert@tbs-sct.gc.ca', 'num_tags': 0, 'contributor': {'fr': '', 'en': ''}, 'frequency': 'P1Y', 'keywords': {'fr': ['Dépenses par programme', 'Rapport sur les plans et les priorités', 'RPP', 'plan ministériel'], 'en': ['program spending', 'departmental plan', 'DP', 'RPP', 'reports on plan and priorities']}, 'data_series_issue_identification': {'fr': '', 'en': ''}, 'ready_to_publish': 'true', 'id': '4535f6d2-eb2a-4339-a4bb-aaa2f0965da3', 'metadata_created': '2017-07-27T14:44:47.066024', 'subject': ['government_and_politics'], 'spatial_representation_type': [], 'metadata_modified': '2017-08-10T18:30:12.896095', 'author': None, 'author_email': None, 'geographic_region': [], 'position_name': {}, 'portal_release_date': '2017-07-27', 'digital_object_identifier': '', 'state': 'active', 'version': None, 'relationships_as_object': [], 'creator_user_id': 'aa584ab4-544c-4c5c-81da-d1cff9bd96fa', 'title_translated': {'fr': 'Dépenses prévues par programme', 'en': 'Planned Spending by Program'}, 'type': 'dataset', 'resources': [{'resource_group_id': '618ab875-cc57-410d-bf5f-4d162cede786', 'cache_last_updated': None, 'package_id': '4535f6d2-eb2a-4339-a4bb-aaa2f0965da3', 'datastore_active': False, 'id': '363bbc09-20f0-47d9-81ef-3bb53ae00b16', 'state': 'active', 'name_translated': {'fr': 'Dépenses prévues par programme, 2014-17', 'en': 'Planned Spending by Progra ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-32dbd8d655ca> in <module>
#       6
#       7 # Use the json module to dump a dictionary to a string for posting.
# ----> 8 data_string = urllib.quote(json.dumps({'id': 'data-explorer'}))
#       9
#      10 # Make the HTTP request.
#
# AttributeError: module 'urllib' has no attribute 'quote'
